# %%
features = ['elevation', 'Wind Direction', 'Wind Speed', 'Min Temp', 'Max Temp', 'Humidity', 'Precipitation', 'Drought Index', 'Vegetation', 'Population Density', 'ERC', 'Previous Fire Mask']

# %%
feature_to_idx = {}
for i, x in enumerate(features):
    feature_to_idx[x] = i
    
feature_to_idx
# Out:
# {'elevation': 0,
#  'Wind Direction': 1,
#  'Wind Speed': 2,
#  'Min Temp': 3,
#  'Max Temp': 4,
#  'Humidity': 5,
#  'Precipitation': 6,
#  'Drought Index': 7,
#  'Vegetation': 8,
#  'Population Density': 9,
#  'ERC': 10,
#  'Previous Fire Mask': 11}

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras import layers
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Dropout, concatenate, Flatten, UpSampling2D,Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.models import Model, load_model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.initializers import glorot_uniform
import scipy.misc
from matplotlib.pyplot import imshow
# %matplotlib inline

import keras.backend as K
K.set_image_data_format('channels_last')
K.set_learning_phase(1)
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2_p38/lib/python3.8/site-packages/keras/backend.py:414: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '

# %%
X_train = np.load('X_train_final.npy')
Y_train = np.load('Y_train_final.npy')
X_val = np.load('X_val.npy')
Y_val = np.load('Y_val.npy')
Yuncertain = np.unique(np.where(Y_val==-1))
Y_val = np.delete(Y_val, Yuncertain, 0)
X_val = np.delete(X_val, Yuncertain, 0)
Y_train = np.where(Y_train == -1, 0, Y_train)
Y_val = np.where(Y_val == -1, 0, Y_val)
val_fire = np.unique(np.where(X_val[:,:,:,11]==1))
X_val_fire = X_val[val_fire]
Y_val_fire = Y_val[val_fire]

# %%
features7 = [0,1,2,4,7,8,11]
X_train7 = X_train[:,:,:,features7]
X_val7 = X_val[:,:,:,features7]
X_val_fire7 = X_val_fire[:,:,:,features7]
[m, n_h, n_w, n_c] = X_train7.shape

# %%
# Evaluation Metrics : Dice Coefficient and Intersection over Union

def dice_coef(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def iou(y_true, y_pred, smooth=1):
    intersection = K.sum(y_true * y_pred)
    sum_ = K.sum(y_true + y_pred)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

# %%
# Contraction Path
s=1

X = Input((n_h, n_w, n_c))

dropout = 0.1

c1 = Conv2D(16, (3,3), strides =(s,s), padding='same', activation = 'relu', kernel_initializer = 'he_normal')(X)
c1 = Dropout(dropout)(c1)
c1 = Conv2D(16, (3,3), strides =(s,s), padding = 'same', activation='relu', kernel_initializer = 'he_normal')(c1)
c1 = BatchNormalization(axis=3)(c1)
c1 = Activation('relu')(c1)
p1 = MaxPooling2D((2,2))(c1)
    
c2 = Conv2D(32, (3,3), strides =(s,s), padding='same', activation = 'relu', kernel_initializer = 'he_normal')(p1)
c2 = Dropout(dropout)(c2)
c2 = Conv2D(32, (3,3), strides =(s,s), padding = 'same', kernel_initializer = 'he_normal')(c2)
c2 = BatchNormalization(axis=3)(c2)
c2 = Activation('relu')(c2)
p2 = MaxPooling2D((2,2))(c2)
   
c3 = Conv2D(64, (3,3), strides =(s,s), padding='same', activation = 'relu', kernel_initializer = 'he_normal')(p2)
c3 = Dropout(dropout)(c3)
c3 = Conv2D(64, (3,3), strides =(s,s), padding = 'same', kernel_initializer = 'he_normal')(c3)
c3 = BatchNormalization(axis=3)(c3)
c3 = Activation('relu')(c3)
p3 = MaxPooling2D((2,2))(c3)
    
c4 = Conv2D(128, (3,3), activation='relu', padding='same', kernel_initializer='he_normal')(p3)
c4 = Dropout(dropout)(c4)
c4 = Conv2D(128, (3,3), padding='same', kernel_initializer='he_normal')(c4)
c4 = BatchNormalization(axis=3)(c4)
c4 = Activation('relu')(c4)  
    
 # Expansion path

u5 = UpSampling2D(size = (2,2))(c4)
u5 = concatenate([u5, c3])
c5 = Conv2D(64, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(u5)
c5 = Dropout(dropout)(c5)
c5 = Conv2D(64, (3,3), kernel_initializer='he_normal', padding='same')(c5)
c5 = BatchNormalization(axis=3)(c5)
c5 = Activation('relu')(c5)                                                                        
    
u6 = UpSampling2D(size = (2,2))(c5)
u6 = concatenate([u6, c2])
c6 = Conv2D(32, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
c6 = Dropout(dropout)(c6)
c6 = Conv2D(32, (3,3), kernel_initializer='he_normal', padding='same')(c6)
c6 = BatchNormalization(axis=3)(c6)
c6 = Activation('relu')(c6) 
    
u7 = UpSampling2D(size = (2,2))(c6)
u7 = concatenate([u7, c1])
c7 = Conv2D(16, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
c7 = Dropout(dropout)(c7)
c7 = Conv2D(16, (3,3), kernel_initializer='he_normal', padding='same')(c7)
c7 = BatchNormalization(axis=3)(c7)
c7 = Activation('relu')(c7)                                                                        
                                                        
    
outputs = Conv2D(1, (1,1), activation = 'sigmoid')(c7)
# Out:
# 2022-05-31 20:08:41.906340: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-05-31 20:08:41.906396: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (ip-172-31-22-219): /proc/driver/nvidia/version does not exist
# 2022-05-31 20:08:41.906908: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model = Model(inputs = X, outputs = outputs)

# %%
from tensorflow.keras.optimizers import Adam

# %%
epochs = 200
learning_rate = 1e-3
decay_rate = learning_rate/epochs
batch_size=64
opt = Adam(lr=learning_rate, beta_1=0.9, beta_2=0.999, epsilon=1e-8, decay=decay_rate, amsgrad=False)
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2_p38/lib/python3.8/site-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
model.compile(optimizer=opt, loss='binary_crossentropy', metrics=[dice_coef, iou])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 7)]  0           []
#
#  conv2d (Conv2D)                (None, 32, 32, 16)   1024        ['input_1[0][0]']
#
#  dropout (Dropout)              (None, 32, 32, 16)   0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 16)   2320        ['dropout[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 16)  64          ['conv2d_1[0][0]']
#  alization)
#
#  activation (Activation)        (None, 32, 32, 16)   0           ['batch_normalization[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 16, 16, 16)   0           ['activation[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 16, 16, 32)   4640        ['max_pooling2d[0][0]']
#
#  dropout_1 (Dropout)            (None, 16, 16, 32)   0           ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 16, 16, 32)   9248        ['dropout_1[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 16, 16, 32)  128         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 16, 16, 32)   0           ['batch_normalization_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 32)    0           ['activation_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 8, 8, 64)     18496       ['max_pooling2d_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 8, 8, 64)     0           ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 8, 8, 64)     36928       ['dropout_2[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 8, 8, 64)    256         ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 8, 8, 64)     0           ['batch_normalization_2[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 4, 4, 64)    0           ['activation_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 4, 4, 128)    73856       ['max_pooling2d_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 4, 4, 128)    0           ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 4, 4, 128)    147584      ['dropout_3[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 4, 4, 128)   512         ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 4, 4, 128)    0           ['batch_normalization_3[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 8, 8, 128)    0           ['activation_3[0][0]']
#
#  concatenate (Concatenate)      (None, 8, 8, 192)    0           ['up_sampling2d[0][0]',
#                                                                   'activation_2[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 8, 8, 64)     110656      ['concatenate[0][0]']
#
#  dropout_4 (Dropout)            (None, 8, 8, 64)     0           ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 8, 8, 64)     36928       ['dropout_4[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 8, 8, 64)    256         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 8, 8, 64)     0           ['batch_normalization_4[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 16, 16, 64)  0           ['activation_4[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 16, 16, 96)   0           ['up_sampling2d_1[0][0]',
#                                                                   'activation_1[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 32)   27680       ['concatenate_1[0][0]']
#
#  dropout_5 (Dropout)            (None, 16, 16, 32)   0           ['conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 32)   9248        ['dropout_5[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 16, 16, 32)  128         ['conv2d_11[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 16, 16, 32)   0           ['batch_normalization_5[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 32, 32, 32)  0           ['activation_5[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 32, 32, 48)   0           ['up_sampling2d_2[0][0]',
#                                                                   'activation[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 16)   6928        ['concatenate_2[0][0]']
#
#  dropout_6 (Dropout)            (None, 32, 32, 16)   0           ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 16)   2320        ['dropout_6[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_13[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_6[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 1)    17          ['activation_6[0][0]']
#
# ==================================================================================================
# Total params: 489,281
# Trainable params: 488,577
# Non-trainable params: 704
# __________________________________________________________________________________________________

# %%
history = model.fit(X_train7, Y_train, epochs = epochs, batch_size = batch_size)
# Out:
# Epoch 1/200
# 170/170 [==============================] - 24s 125ms/step - loss: 0.2844 - dice_coef: 0.0462 - iou: 0.0237
# Epoch 2/200
# 170/170 [==============================] - 21s 126ms/step - loss: 0.1365 - dice_coef: 0.0581 - iou: 0.0301
# Epoch 3/200
# 170/170 [==============================] - 21s 125ms/step - loss: 0.1002 - dice_coef: 0.1381 - iou: 0.0745
# Epoch 4/200
# 170/170 [==============================] - 21s 125ms/step - loss: 0.0915 - dice_coef: 0.1623 - iou: 0.0886
# Epoch 5/200
# 170/170 [==============================] - 21s 125ms/step - loss: 0.0875 - dice_coef: 0.1747 - iou: 0.0960
# Epoch 6/200
# 170/170 [==============================] - 21s 126ms/step - loss: 0.0861 - dice_coef: 0.1805 - iou: 0.0995
# Epoch 7/200
# 170/170 [==============================] - 21s 125ms/step - loss: 0.0852 - dice_coef: 0.1861 - iou: 0.1029
# Epoch 8/200
# 170/170 [==============================] - 21s 125ms/step - loss: 0.0846 - dice_coef: 0.1876 - iou: 0.1038
# Epoch 9/200
# 170/170 [==============================] - 21s 125ms/step - loss: 0.0838 - dice_coef: 0.1909 - iou: 0.1058
# Epoch 10/200
# 170/170 [==============================] - 21s 126ms/step - loss: 0.0833 - dice_coef: 0.1922 - iou: 0.1066
# Epoch 11/200
# 170/170 [==============================] - 21s 126ms/step - loss: 0.0830 - dice_coef: 0.1956 - iou: 0.1087
# Epoch 12/200
# 170/170 [==============================] - 21s 125ms/step - loss: 0.0826 - dice_coef: 0.1969 - iou: 0.1095
# Epoch 13/200
# 170/170 [==============================] - 21s 126ms/step - loss: 0.0820 - dice_coef: 0.1993 - iou: 0.1110
# Epoch 14/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0817 - dice_coef: 0.2014 - iou: 0.1123
# Epoch 15/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0816 - dice_coef: 0.2014 - iou: 0.1123
# Epoch 16/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0812 - dice_coef: 0.2063 - iou: 0.1153
# Epoch 17/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0807 - dice_coef: 0.2059 - iou: 0.1151
# Epoch 18/200
# 170/170 [==============================] - 21s 125ms/step - loss: 0.0805 - dice_coef: 0.2076 - iou: 0.1161
# Epoch 19/200
# 170/170 [==============================] - 21s 125ms/step - loss: 0.0804 - dice_coef: 0.2094 - iou: 0.1173
# Epoch 20/200
# 170/170 [==============================] - 21s 125ms/step - loss: 0.0800 - dice_coef: 0.2116 - iou: 0.1186
# Epoch 21/200
# 170/170 [==============================] - 21s 125ms/step - loss: 0.0794 - dice_coef: 0.2137 - iou: 0.1199
# Epoch 22/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0792 - dice_coef: 0.2148 - iou: 0.1207
# Epoch 23/200
# 170/170 [==============================] - 21s 125ms/step - loss: 0.0790 - dice_coef: 0.2158 - iou: 0.1214
# Epoch 24/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0787 - dice_coef: 0.2184 - iou: 0.1231
# Epoch 25/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0786 - dice_coef: 0.2195 - iou: 0.1238
# Epoch 26/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0780 - dice_coef: 0.2209 - iou: 0.1246
# Epoch 27/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0777 - dice_coef: 0.2239 - iou: 0.1265
# Epoch 28/200
# 170/170 [==============================] - 21s 125ms/step - loss: 0.0774 - dice_coef: 0.2268 - iou: 0.1285
# Epoch 29/200
# 170/170 [==============================] - 21s 125ms/step - loss: 0.0772 - dice_coef: 0.2270 - iou: 0.1287
# Epoch 30/200
# 170/170 [==============================] - 21s 125ms/step - loss: 0.0768 - dice_coef: 0.2301 - iou: 0.1307
# Epoch 31/200
# 170/170 [==============================] - 21s 125ms/step - loss: 0.0763 - dice_coef: 0.2342 - iou: 0.1334
# Epoch 32/200
# 170/170 [==============================] - 21s 125ms/step - loss: 0.0756 - dice_coef: 0.2382 - iou: 0.1360
# Epoch 33/200
# 170/170 [==============================] - 21s 125ms/step - loss: 0.0754 - dice_coef: 0.2408 - iou: 0.1376
# Epoch 34/200
# 170/170 [==============================] - 21s 125ms/step - loss: 0.0749 - dice_coef: 0.2444 - iou: 0.1401
# Epoch 35/200
# 170/170 [==============================] - 21s 125ms/step - loss: 0.0748 - dice_coef: 0.2467 - iou: 0.1415
# Epoch 36/200
# 170/170 [==============================] - 21s 126ms/step - loss: 0.0740 - dice_coef: 0.2516 - iou: 0.1448
# Epoch 37/200
# 170/170 [==============================] - 21s 125ms/step - loss: 0.0737 - dice_coef: 0.2528 - iou: 0.1457
# Epoch 38/200
# 170/170 [==============================] - 21s 125ms/step - loss: 0.
200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0422 - dice_coef: 0.5476 - iou: 0.3786
# Epoch 162/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0422 - dice_coef: 0.5472 - iou: 0.3785
# Epoch 163/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0420 - dice_coef: 0.5480 - iou: 0.3792
# Epoch 164/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0420 - dice_coef: 0.5493 - iou: 0.3803
# Epoch 165/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0418 - dice_coef: 0.5524 - iou: 0.3833
# Epoch 166/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0419 - dice_coef: 0.5495 - iou: 0.3804
# Epoch 167/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0419 - dice_coef: 0.5490 - iou: 0.3803
# Epoch 168/200
# 170/170 [==============================] - 21s 126ms/step - loss: 0.0418 - dice_coef: 0.5511 - iou: 0.3820
# Epoch 169/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0415 - dice_coef: 0.5529 - iou: 0.3839
# Epoch 170/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0417 - dice_coef: 0.5531 - iou: 0.3838
# Epoch 171/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0414 - dice_coef: 0.5538 - iou: 0.3847
# Epoch 172/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0414 - dice_coef: 0.5550 - iou: 0.3856
# Epoch 173/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0413 - dice_coef: 0.5544 - iou: 0.3853
# Epoch 174/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0412 - dice_coef: 0.5576 - iou: 0.3882
# Epoch 175/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0413 - dice_coef: 0.5557 - iou: 0.3864
# Epoch 176/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0410 - dice_coef: 0.5573 - iou: 0.3881
# Epoch 177/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0409 - dice_coef: 0.5579 - iou: 0.3887
# Epoch 178/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0410 - dice_coef: 0.5593 - iou: 0.3898
# Epoch 179/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0405 - dice_coef: 0.5625 - iou: 0.3929
# Epoch 180/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0409 - dice_coef: 0.5595 - iou: 0.3900
# Epoch 181/200
# 170/170 [==============================] - 21s 125ms/step - loss: 0.0405 - dice_coef: 0.5622 - iou: 0.3928
# Epoch 182/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0406 - dice_coef: 0.5607 - iou: 0.3913
# Epoch 183/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0403 - dice_coef: 0.5638 - iou: 0.3943
# Epoch 184/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0405 - dice_coef: 0.5635 - iou: 0.3940
# Epoch 185/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0406 - dice_coef: 0.5616 - iou: 0.3919
# Epoch 186/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0403 - dice_coef: 0.5647 - iou: 0.3951
# Epoch 187/200
# 170/170 [==============================] - 21s 125ms/step - loss: 0.0404 - dice_coef: 0.5629 - iou: 0.3935
# Epoch 188/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0401 - dice_coef: 0.5662 - iou: 0.3966
# Epoch 189/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0401 - dice_coef: 0.5653 - iou: 0.3957
# Epoch 190/200
# 170/170 [==============================] - 21s 125ms/step - loss: 0.0399 - dice_coef: 0.5681 - iou: 0.3982
# Epoch 191/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0399 - dice_coef: 0.5665 - iou: 0.3968
# Epoch 192/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0398 - dice_coef: 0.5696 - iou: 0.3998
# Epoch 193/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0397 - dice_coef: 0.5688 - iou: 0.3990
# Epoch 194/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0399 - dice_coef: 0.5674 - iou: 0.3978
# Epoch 195/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0397 - dice_coef: 0.5700 - iou: 0.4002
# Epoch 196/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0396 - dice_coef: 0.5686 - iou: 0.3991
# Epoch 197/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0399 - dice_coef: 0.5666 - iou: 0.3972
# Epoch 198/200
# 170/170 [==============================] - 21s 126ms/step - loss: 0.0396 - dice_coef: 0.5702 - iou: 0.4003
# Epoch 199/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0392 - dice_coef: 0.5754 - iou: 0.4054
# Epoch 200/200
# 170/170 [==============================] - 21s 124ms/step - loss: 0.0393 - dice_coef: 0.5726 - iou: 0.4027

# %%
print(history.history.keys())
plt.figure(figsize=(20,10))
plt.subplot(122)
plt.plot(history.history['loss'])
plt.xlabel('Epoch', fontsize=15)
plt.ylabel('Binary Crossentropy Loss', fontsize=15)
plt.title('Loss', fontsize=15)
plt.subplot(221)
plt.plot(history.history['dice_coef'])
plt.ylabel('Dice Coefficient', fontsize=15)
plt.title('Dice Coefficient', fontsize=15)
plt.subplot(223)
plt.plot(history.history['iou'])
plt.xlabel('Epoch', fontsize=15)
plt.ylabel('IOU', fontsize=15)
plt.title('IOU', fontsize=15)
plt.suptitle('7 features\nLearning Rate = {}, MBSize = {}, Adam Optimizer'.format(learning_rate, batch_size), fontsize=20)
# Out:
# dict_keys(['loss', 'dice_coef', 'iou'])
# Text(0.5, 0.98, '7 features\nLearning Rate = 0.001, MBSize = 64, Adam Optimizer')

# %%
np.save('V3_7features', history.history)

# %%
model.evaluate(X_val_fire7, Y_val_fire)
# Out:
# 26/26 [==============================] - 0s 16ms/step - loss: 0.1582 - dice_coef: 0.2397 - iou: 0.1372
# [0.15823426842689514, 0.23965653777122498, 0.1372230350971222]

# %%
model.save('UnetV3_200')
# Out:
# 2022-05-31 21:29:18.776175: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: UnetV3_200/assets

# %%
def plot_val(i):
    x = X_val_fire7[i,:,:,:]
    x = np.expand_dims(x, axis=0)
    y = model.predict(x)
    y = np.where(y>0.5, 1, 0)
    plt.figure(figsize = (20,6))
    plt.subplot(131)
    plt.imshow(X_val_fire7[i,:,:,6], cmap = 'Wistia')
    plt.title('Previous Day')
    plt.colorbar()
    plt.clim([0,1])
    plt.subplot(132)
    plt.imshow(Y_val_fire[i,:,:], cmap = 'Wistia')
    plt.title('Next Day Fire Mask')
    plt.colorbar()
    plt.clim([0,1])
    plt.subplot(133)
    plt.imshow(y[0,:,:,0], cmap = 'Wistia')
    plt.title('Predicted Fire Mask')
    plt.colorbar()
    plt.clim([0,1])
    plt.clim([0,1])
    plt.suptitle('Previous Day Mask, True Mask v/s Prediction (Val Data) #{}'.format(i), fontsize=15)
    
def plot_train(i):
    x = X_train[i,:,:,:]
    x = np.expand_dims(x, axis=0)
    y = model.predict(x)
    y = np.where(y>0.5, 1, 0)
    plt.figure(figsize = (20,6))
    plt.subplot(131)
    plt.imshow(X_train[i,:,:,11], cmap = 'Wistia')
    plt.title('Previous Day')
    plt.colorbar()
    plt.clim([0,1])
    plt.subplot(132)
    plt.imshow(Y_train[i,:,:], cmap = 'Wistia')
    plt.title('Next Day Fire Mask')
    plt.colorbar()
    plt.subplot(133)
    plt.clim([0,1])
    plt.imshow(y[0,:,:,0], cmap = 'Wistia')
    plt.title('Predicted Fire Mask')
    plt.colorbar()
    plt.clim([0,1])
    plt.suptitle('Previous Day Mask, True Mask v/s Prediction (Training Data) #{}'.format(i), fontsize=15)

# %%
for i in range(520,540):
    plot_val(i)

# %%
plot_val(92)
